# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
## Google setup
from google.colab import drive
drive.mount('/content/drive')
code_path = "/content/drive/Shared drives/EGG/Python_Codes"
import sys
sys.path.append(code_path)
# %cd /content/drive/Shared drives/EGG/Python Codes
# !ls

# %%
import numpy as np
import scipy as sp
import scipy.io
from scipy.ndimage import gaussian_filter
from scipy import signal
import pandas as pd
pd.set_option('display.max_colwidth', -1,'display.max_rows',999)
import time, datetime, sys, os
# import ECG

# import ipympl
import matplotlib.pyplot as plt
#%matplotlib ipympl
# %matplotlib inline
import matplotlib.mlab as mlab
import matplotlib.dates as mdates
import seaborn as sns
sns.set(rc={'image.cmap': 'jet'},style="ticks",font_scale=1.2)


# directory containing HRVfreq.py
#sys.path.append("../../ECGanalytics/")
#from HRVfreq import *

# %%
RID_list = ['SD200124-152100-AW-test']
data_dir = '/content/drive/Shared drives/EGG/MicroSD_Data/'

# %%
## Change Directory to load data
# %cd $data_dir
# %ls
# Out:
# /content/drive/Shared drives/EGG/MicroSD_Data
# 'Data plotting.ipynb'           SD200124-123600-AW-3leadEKG.csv
# 'File Naming Convention.gdoc'   SD200124-152100-AW-test.csv
#  SD200122-140000-AW-test.csv    SD200124-152100-AW-test-processed.mat
